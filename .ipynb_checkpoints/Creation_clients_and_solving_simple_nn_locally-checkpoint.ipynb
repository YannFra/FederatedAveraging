# %%
# prerequisites
import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np

import matplotlib.pyplot as plt

import syft as sy
hook=sy.TorchHook(torch)
# Out:
# Falling back to insecure randomness since the required custom op could not be found for the installed version of TensorFlow. Fix this by compiling custom ops. Missing file was '/root/anaconda3/lib/python3.7/site-packages/tf_encrypted/operations/secure_random/secure_random_module_tf_1.15.0.so'
# WARNING:tensorflow:From /root/anaconda3/lib/python3.7/site-packages/tf_encrypted/session.py:24: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
#torch.rand => uniform distribution

dim=100

X1=torch.rand(dim, 1,requires_grad=True) 
X2=torch.rand(dim,1,requires_grad=True)

a_1,b_1=5,-1
a_2,b_2=3,2
y1=a_1*X1+b_1+0.5*torch.randn(dim,1)
y2=a_2*X2+b_2+0.5*torch.randn(dim,1)

# %%
x_axis=np.linspace(0,1,100)

plt.figure(figsize=(20,10))

plt.scatter(X1.detach().numpy(),y1.detach().numpy(),label="Distribution Client 1")
plt.plot(x_axis,a_1*x_axis+b_1,label="Theoretical model 1")

plt.scatter(X2.detach().numpy(),y2.detach().numpy(),label="Distribution Client 2")
plt.plot(x_axis,a_2*x_axis+b_2,label="Theoretical model 2")

plt.legend()
plt.show()

# %%
#Create a simple neural network for the linear regression
class simple_network(nn.Module):
    
    def __init__(self):
        super(simple_network, self).__init__()
        
        self.l1=nn.Linear (1,1)
        
    
    def predict(self,x):
        
        return self.l1(x)        


reg_1=simple_network()
optimizer1=optim.Adam(reg_1.parameters())

reg_2=simple_network()
optimizer2=optim.Adam(reg_2.parameters())

# %%
loss_f=nn.MSELoss()
def train_nn(model,optimizer,x,y,epoch):
        optimizer.zero_grad()
        
        y_predict=model.predict(x)

        loss=loss_f(y_predict,y)
        loss.backward(retain_graph=True)
        
        optimizer.step() 
        
        if epoch%1000==0:
            
            print("Training MSE for epoch "+str(epoch+1)+": "+ str(loss.item()))

# %%
reg_1.state_dict()
# Out:
# OrderedDict([('l1.weight', tensor([[-0.0473]])),
#              ('l1.bias', tensor([-0.0177]))])

# %%
for epoch in range(10001):
    train_nn(reg_1,optimizer1,X1,y1,epoch)
    train_nn(reg_2,optimizer2,X2,y2,epoch)
# Out:
# Training MSE for epoch 1: 5.3814287185668945
# Training MSE for epoch 1: 8.046764373779297
# Training MSE for epoch 1001: 2.134113311767578
# Training MSE for epoch 1001: 2.4342429637908936
# Training MSE for epoch 2001: 1.5167309045791626
# Training MSE for epoch 2001: 0.6177665591239929
# Training MSE for epoch 3001: 1.2000609636306763
# Training MSE for epoch 3001: 0.30456286668777466
# Training MSE for epoch 4001: 0.8796584606170654
# Training MSE for epoch 4001: 0.2841801345348358
# Training MSE for epoch 5001: 0.6076117157936096
# Training MSE for epoch 5001: 0.2788577973842621
# Training MSE for epoch 6001: 0.41650474071502686
# Training MSE for epoch 6001: 0.2743706703186035
# Training MSE for epoch 7001: 0.30831998586654663
# Training MSE for epoch 7001: 0.2718060612678528
# Training MSE for epoch 8001: 0.26369839906692505
# Training MSE for epoch 8001: 0.27103182673454285
# Training MSE for epoch 9001: 0.25301316380500793
# Training MSE for epoch 9001: 0.27094554901123047
# Training MSE for epoch 10001: 0.25203144550323486
# Training MSE for epoch 10001: 0.2709435522556305

# %%
y_pred_1=reg_1.predict(X1).detach()
y_pred_2=reg_2.predict(X2).detach()


x_axis=np.linspace(0,1,100)

plt.figure(figsize=(20,10))

plt.scatter(X1.detach().numpy(),y1.detach().numpy(),label="Distribution Client 1")
plt.plot(x_axis,a_1*x_axis+b_1,label="Theoretical model 1")
plt.scatter(X1.detach().numpy(),y_pred_1.detach().numpy(),label="Linear Regression 1")

plt.scatter(X2.detach().numpy(),y2.detach().numpy(),label="Distribution Client 2")
plt.plot(x_axis,a_2*x_axis+b_2,label="Theoretical model 2")
plt.scatter(X2.detach().numpy(),y_pred_2.detach().numpy(),label="Linear Regression 2")

plt.legend()
plt.show()
